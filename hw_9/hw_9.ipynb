# %%
import pymc3 as pm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
df = pd.read_csv("location_data_hw9_2018.csv"); df.head(3)
# Out:
#           t  red_pos_X  red_pos_Y  blue_pos_X  blue_pos_Y
# 0  1.718397   1.330174   0.993564    1.081700   -1.295918
# 1  2.998056   1.310404   1.012772    1.004997   -1.254394
# 2  6.015073   1.270312   1.028386    1.113696   -1.321257

# %%
fig, ax = plt.subplots()
ax.plot(df["red_pos_X"], df["red_pos_Y"], color="r")
ax.plot(df["blue_pos_X"], df["blue_pos_Y"], color="b")
ax.tick_params(which="both", right=True, top=True, direction="in")
ax.set_xlabel("x position", fontsize=15)
ax.set_ylabel("y position", fontsize=15)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_red, x_blue = np.array(df["red_pos_X"]), np.array(df["blue_pos_X"])
y_red, y_blue = np.array(df["red_pos_Y"]), np.array(df["blue_pos_Y"])

# %%
with pm.Model() as model:
    v = pm.Normal("theta", mu=0, sd=)
    
    # Likelihood 
    Y_obs = pm.Normal('Y_obs', mu=mu, sd=sigma, observed=Y)

# %%
with model:
    step = pm.NUTS()
    trace = pm.sample(50000, step=step, njobs=1)

# %%
pm.traceplot(trace[1000:][::5])
